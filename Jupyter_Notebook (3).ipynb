# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on Skill Network lab

# %% [markdown]
# **UDYAN SHARMA**
# i want to be a data scientist.

# %% [markdown]
# _I am interseted in data science because its like to get the mystry solve from the enormous amounts of data_

# %% [markdown]
# ### it will display the user entered name follwed by Good Morning using input () function

# %%
name = input("Enter your name\n")
print("Good Morning, " + name)

# %% [markdown]
# https://in.coursera.org/
